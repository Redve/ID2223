# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import ensemble, tree, linear_model
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# %pip install geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 40.3/40.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 125.4/125.4 kB 7.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.
# WARNING: Ignoring invalid distribution -rotobuf (c:\program files\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\program files\python310\lib\site-packages)

# %%
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

def get_coordinates(location_name):
    geolocator = Nominatim(user_agent="my_geocoder")
    location = geolocator.geocode(location_name)
    if location:
        return location.latitude, location.longitude
    else:
        return None

def calculate_distance(origin, destination):
    origin_coords = get_coordinates(origin)
    destination_coords = get_coordinates(destination)

    if origin_coords and destination_coords:
        distance = geodesic(origin_coords, destination_coords).kilometers
        return distance
    else:
        return None

# Example usage
origin_place = "Sollentuna, Stockholm"
destination_place = "London, UK"

distance = calculate_distance(origin_place, destination_place)

if distance is not None:
    print(f"The distance between {origin_place} and {destination_place} is approximately {distance:.2f} kilometers.")
else:
    print("Error: Unable to get coordinates for one or both locations.")
# Out:
# The distance between Sollentuna, Stockholm and London, UK is approximately 1438.35 kilometers.

# %%
bostadsrattStockholm = pd.read_csv("C:/Users/Adnane/Downloads/bostadsrattStockholm.csv")
fritidshusStockholm = pd.read_csv("C:/Users/Adnane/Downloads/fritidScraper.csv")
RadHusStockholm = pd.read_csv("C:/Users/Adnane/Downloads/RadHusStockholm.csv")
villaStockholm = pd.read_csv("C:/Users/Adnane/Downloads/villaStockholm.csv")


bostadsrattStockholm['type'] = 'bostadsratt'
fritidshusStockholm['type'] = 'fritidshus'
RadHusStockholm['type'] = 'RadHus'
villaStockholm['type'] = 'villa'
#combine all csv files
combined = pd.concat([bostadsrattStockholm,fritidshusStockholm,RadHusStockholm,villaStockholm],ignore_index=True)

# %%
combined.head()
# Out:
#    price_per_m2         asking_price price_evolution typeProperty typeOfForm  \
# 0  1 395 000 kr  -145 000 kr (-10 %)        Lägenhet  Bostadsrätt      2 rum
# 1  2 050 000 kr    -70 000 kr (-3 %)        Lägenhet  Bostadsrätt      2 rum
# 2  6 495 000 kr    -70 000 kr (-1 %)        Lägenhet  Bostadsrätt      5 rum
# 3  3 750 000 kr   -300 000 kr (-8 %)        Lägenhet  Bostadsrätt      4 rum
# 4  7 795 000 kr   -345 000 kr (-4 %)        Lägenhet  Bostadsrätt      4 rum
#
#     rooms size bisize balkong tomtarea     buildArea cost            uteplats  \
# 0   55 m²  NaN     Ja     NaN     1969   3 444 kr/år  NaN                 NaN
# 1   42 m²  NaN     Ja     NaN     2020   4 500 kr/år  NaN       3, hiss finns
# 2  104 m²  NaN     Ja     NaN     2022           NaN  NaN  4 av 4, hiss finns
# 3   94 m²  NaN     Ja     NaN     1986  11 280 kr/år  NaN  1 av 3, hiss finns
# 4  111 m²  NaN    Nej     NaN     2021  22 332 kr/år   Ja                 NaN
#
# ...

# %%
#from the word to - put that in a different column, and from the comma to the - put that in a different column and from the - onwards put that in a different column




#how many rows in the dataframe
combined['precise_location'] = ''
combined['date_sold'] = ''
for i in range(0, len(combined)):
    a = 0
    a = combined['floor'].iloc[i].split(' - ')
    #if a[3] exist
    if(len(a) == 4):
        z = a[2]
        combined['precise_location'].iloc[i] = z
        a[3] = a[3].replace('Såld', '')
        combined['date_sold'].iloc[i] = a[3]
    elif(len(a) == 5):
        z = a[3]
        combined['precise_location'].iloc[i] = z
        a[4] = a[4].replace('Såld', '')
        combined['date_sold'].iloc[i] = a[4]
    elif(len(a) == 6):
        z = a[4]
        combined['precise_location'].iloc[i] = z
        a[5] = a[5].replace('Såld', '')
        combined['date_sold'].iloc[i] = a[5]
    else:
        combined['precise_location'].iloc[i] = a[1]
        a[2] = a[2].replace('Såld', '')
        combined['date_sold'].iloc[i] = a[2]
    # if a[0] contains Vinterbonat fritidshus, then print a[0] and i
    # if 'Vinterbonat fritidshus' in a[0]:
    #     print(i)


combined['date_sold']
for i in range(0, len(combined)):
    #if the number i is in the srtring of the date sold, then print the number i
    b = 0
    for j in range(10):
        a = str(j)
        if a not in combined['date_sold'].iloc[i]:
            b = b +1
            if(b == 9):
                print(i)
    # if str(i) in combined['date_sold'].iloc[i]:
    #     print(i)


# print(combined['floor'].iloc[6])


# combined['date_sold'].iloc[6]

# %%
combined['precise_location'].iloc[7093]
# Out:
# 'Idalen, Värmdö kommun'

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with 20,000 rows

df = combined

# Number of parts to split the DataFrame into
num_parts = 25

# Split the DataFrame into 25 parts
df_parts = np.array_split(df, num_parts)

# Access each part, for example, print the size of each part
for i, part in enumerate(df_parts):
    print(f"Part {i+1}: {len(part)} rows")

# Now df_parts is a list containing 25 smaller DataFrames
# Out:
# Part 1: 800 rows
# Part 2: 800 rows
# Part 3: 800 rows
# Part 4: 800 rows
# Part 5: 800 rows
# Part 6: 800 rows
# Part 7: 800 rows
# Part 8: 800 rows
# Part 9: 800 rows
# Part 10: 800 rows
# Part 11: 800 rows
# Part 12: 800 rows
# Part 13: 800 rows
# Part 14: 800 rows
# Part 15: 800 rows
# Part 16: 800 rows
# Part 17: 800 rows
# Part 18: 800 rows
# Part 19: 800 rows
# Part 20: 800 rows
# Part 21: 800 rows
# Part 22: 800 rows
# Part 23: 800 rows
# Part 24: 800 rows
# Part 25: 800 rows

# %%
n = 0
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 1
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 2
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# 8
# iteration 9
# 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# 28
# iteration 29
# 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 3
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# 8
# iteration 9
# iteration 10
# iteration 11
# 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# 63
# iteration 64
# iteration 65
# ...

# %%
n = 4
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 5
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 6
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# 37
# iteration 38
# iteration 39
# 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 7
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 8
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 9
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# 45
# iteration 46
# 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 10
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 11
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 12
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 13
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 14
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 15
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 16
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 17
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 18
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 19
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# 57
# iteration 58
# 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 20
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# 58
# iteration 59
# 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 21
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 22
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 23
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# ...

# %%
n = 24
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# 55
# iteration 56
# 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# ...

# %%
n = 25
df_parts[n]['precise_location'] 
df_parts[n]['distance_from_city_center'] = ''
#divide df_parts[n] dataframe in 25 different dataframes
for i in range(0, len(df_parts[n])):
    print('iteration', i)
    a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
    if(a != None):
        df_parts[n]['distance_from_city_center'].iloc[i] = a
    if(a == None):
        a = calculate_distance(df_parts[n]['precise_location'].iloc[i], 'Stockholm, Sweden')
        if(a != None):
            df_parts[n]['distance_from_city_center'].iloc[i] = a
        if(a == None):
            d = df_parts[n]['precise_location'].iloc[i]
            d = d.replace('/', ' ')
            a = calculate_distance(d, 'Stockholm, Sweden')
            if(a != None):
                df_parts[n]['distance_from_city_center'].iloc[i] = a
            if(a == None):
                d = d.split(' ')
                x = ''
                for c in range(len(d)):
                    if c == 0:
                        continue
                    x = x + d[c] + ' '
                a = calculate_distance(x, 'Stockholm, Sweden')
                if(a != None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = a
                if(a == None):
                    df_parts[n]['distance_from_city_center'].iloc[i] = 'not found'
                    print(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [202], line 2
#       1 n = 25
# ----> 2 df_parts[n]['precise_location']
#       3 df_parts[n]['distance_from_city_center'] = ''
#       4 #divide df_parts[n] dataframe in 25 different dataframes
#
# IndexError: list index out of range

# %%
import pandas as pd
import numpy as np

# Assuming df_parts is a list containing 25 smaller DataFrames

# Combine the DataFrame parts back into a single DataFrame
combined_df = pd.concat(df_parts, ignore_index=True)

# Print the size of the combined DataFrame
print("Combined DataFrame Size:", len(combined_df))

# Now 'combined_df' contains all the rows from the original DataFrame
# Out:
# Combined DataFrame Size: 20000

# %%
#Save all the dataframes in different csv files
for i in range(0, len(df_parts)):
    df_parts[i].to_csv('C:/Users/Adnane/OneDrive - Delft University of Technology/Bureaublad/TransformedDataframes/df_parts{}.csv'.format(i))

# %%
#save the dataframe to csv file to path "C:\Users\Adnane\OneDrive - Delft University of Technology\Bureaublad\TransformedDataframes"
combined_df.to_csv('C:/Users/Adnane/OneDrive - Delft University of Technology/Bureaublad/TransformedDataframes/FINISHEDCALCULATEDDISTANCES.csv', index = False)

# %%
count = 0
list1 = []
for i in range(len(combined_df['distance_from_city_center'])):
    if(combined_df['distance_from_city_center'].iloc[i] == 'not found'):
        a = combined_df['precise_location'].iloc[i]
        a = a.split(' ')
        a = a[-2:]
        a = a[0] + ' ' + a[1]
        distance = calculate_distance(a, 'Stockholm, Sweden')
        print('iteration' + ' ' , i)
        if(distance == None):
            print('not found', i)
        else:
            combined_df['distance_from_city_center'].iloc[i] = distance
# Out:
# iteration  530
# iteration  539
# iteration  561
# iteration  634
# iteration  743
# iteration  778
# iteration  784
# iteration  955
# iteration  1006
# iteration  1015
# iteration  1132
# iteration  1161
# iteration  1275
# iteration  1285
# iteration  1328
# iteration  1404
# iteration  1432
# iteration  1478
# iteration  1527
# iteration  1560
# iteration  1574
# iteration  1608
# iteration  1609
# iteration  1628
# iteration  1629
# iteration  1765
# iteration  1859
# iteration  1868
# iteration  1877
# iteration  1894
# iteration  1992
# iteration  1998
# iteration  2145
# iteration  2215
# iteration  2221
# iteration  2228
# iteration  2248
# iteration  2253
# iteration  2269
# iteration  2270
# iteration  2322
# iteration  2344
# iteration  2382
# iteration  2391
# iteration  2392
# iteration  2408
# iteration  2411
# iteration  2463
# iteration  2481
# iteration  2535
# iteration  2540
# iteration  2556
# iteration  2676
# iteration  2879
# iteration  2906
# iteration  2938
# ...

# %%
for i in range(len(combined_df['distance_from_city_center'])):
    if(combined_df['distance_from_city_center'].iloc[i] == 'not found'):
        print(i)

# %%
#save the dataframe to csv file to path "C:\Users\Adnane\OneDrive - Delft University of Technology\Bureaublad\TransformedDataframes"
combined_df.to_csv('C:/Users/Adnane/OneDrive - Delft University of Technology/Bureaublad/TransformedDataframes/FINISHEDCALCULATEDDISTANCES.csv', index = False)

# %%
for i in list1:
    print(combined_df['precise_location'].iloc[i])
# Out:
# Åkersberga Centralt, Österåkers kommun
# Fruängen / Nya Fruängen, Stockholms kommun
# Åkersberga Centralt, Österåkers kommun
# Åkersberga Centralt, Österåkers kommun
# Hässelby Norra Villastad, Stockholms kommun
# Näsby Park Sjösidan, Täby kommun
# Ösby Sjöpark, Värmdö kommun
# Östermalm / Nedre Gärdet, Stockholms kommun
# Gustavsberg Södra Bruksgatorna, Värmdö kommun
# Åkersberga Centralt, Österåkers kommun
# Hässelby Norra Villastad, Stockholms kommun
# Åkersberga Centralt, Österåkers kommun
# Kungsholmen/ Nedre Kungsholmen, Stockholms kommun
# Gustavsberg Farsta Slottsvik, Värmdö kommun
# Gustavsberg Farsta Slottsvik, Värmdö kommun
# Åkersberga Centralt, Österåkers kommun
# Åkersberga Centralt, Österåkers kommun
# Vällingby Parkstad / Råcksta, Stockholms kommun
# Hässelby Norra Villastad, Stockholms kommun
# Södermalm Maria, Stockholms kommun
# Huddinge centralt, Huddinge kommun
# Södra Haninge Slätmossen, Haninge kommun
# Östermalm, Villastan, Stockholms kommun
# ...

# %%
result = [' '.join(line.split()[-3:]) for line in combined_df['precise_location'].iloc[84]]

# Print the result
result = [' '.join(line.split(', ')[-3:]) for line in combined_df['precise_location'].iloc[84]]

a = combined_df['precise_location'].iloc[84]
a = a.split(' ')
a = a[-2:]
print(a)
print(a[0] + ' ' +  a[1])
# Out:
# ['Österåkers', 'kommun']
# Österåkers kommun

# %%
villaStockholm['precise_location'].iloc[14]

split = villaStockholm['precise_location'].iloc[14].split(' ')
print(split)
d = split[1] + ' ' + split[2] + ' ' + split[3] + ' '
print(d)
d = calculate_distance('Sundsvik, Nykvarns kommun', 'Stockholm, Sweden')
print(d)
# Out:
# ['Nykvarn', 'Sundsvik,', 'Nykvarns', 'kommun']
# Sundsvik, Nykvarns kommun
# 37.914659311743065

# %%
villaStockholm['precise_location'].iloc[14]
# Out:
# 'Nykvarn Sundsvik, Nykvarns kommun'

# %%
d = calculate_distance('Södra Villastad, Stockholms kommun', 'Stockholm, Sweden')
print(d)
# Out:
# 15.223555441540647

# %%
print(villaStockholm['floor'].iloc[10])


villaStockholm['date_sold'].iloc[10]
# Out:
# Villa - Rådmansö - Södersvik, Norrtälje kommun - Såld 28 december 2023
# 'Södersvik, Norrtälje kommun'

# %%
print(calculate_distance('Södersvik, Norrtälje kommun', 'Stockholm, Sweden'))
# Out:
# 67.2646893394931

# %%
villaStockholm['floor'].iloc[0]
print(calculate_distance('Nacka kommun', 'Stockholm, Sweden'))
# Out:
# 7.893776752994627
